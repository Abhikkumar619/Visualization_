# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x=np.linspace(1,30,100)

# %%
x
# Out:
# array([ 1.        ,  1.29292929,  1.58585859,  1.87878788,  2.17171717,
#         2.46464646,  2.75757576,  3.05050505,  3.34343434,  3.63636364,
#         3.92929293,  4.22222222,  4.51515152,  4.80808081,  5.1010101 ,
#         5.39393939,  5.68686869,  5.97979798,  6.27272727,  6.56565657,
#         6.85858586,  7.15151515,  7.44444444,  7.73737374,  8.03030303,
#         8.32323232,  8.61616162,  8.90909091,  9.2020202 ,  9.49494949,
#         9.78787879, 10.08080808, 10.37373737, 10.66666667, 10.95959596,
#        11.25252525, 11.54545455, 11.83838384, 12.13131313, 12.42424242,
#        12.71717172, 13.01010101, 13.3030303 , 13.5959596 , 13.88888889,
#        14.18181818, 14.47474747, 14.76767677, 15.06060606, 15.35353535,
#        15.64646465, 15.93939394, 16.23232323, 16.52525253, 16.81818182,
#        17.11111111, 17.4040404 , 17.6969697 , 17.98989899, 18.28282828,
#        18.57575758, 18.86868687, 19.16161616, 19.45454545, 19.74747475,
#        20.04040404, 20.33333333, 20.62626263, 20.91919192, 21.21212121,
#        21.50505051, 21.7979798 , 22.09090909, 22.38383838, 22.67676768,
#        22.96969697, 23.26262626, 23.55555556, 23.84848485, 24.14141414,
#        24.43434343, 24.72727273, 25.02020202, 25.31313131, 25.60606061,
#        25.8989899 , 26.19191919, 26.48484848, 26.77777778, 27.07070707,
#        27.36363636, 27.65656566, 27.94949495, 28.24242424, 28.53535354,
#        28.82828283, 29.12121212, 29.41414141, 29.70707071, 30.        ])

# %%
y=np.sin(x)

# %%
y
# Out:
# array([ 0.84147098,  0.96164271,  0.99988657,  0.95294434,  0.82481532,
#         0.62641554,  0.37464782,  0.0909617 , -0.20047397, -0.47483011,
#        -0.70873275, -0.88225437, -0.98061167, -0.99542503, -0.92543241,
#        -0.7765969 , -0.56159863, -0.29875454, -0.01045784,  0.27872982,
#         0.54417089,  0.76325091,  0.91730521,  0.993209  ,  0.98449561,
#         0.89190739,  0.72333245,  0.49313267,  0.22092008, -0.07011396,
#        -0.35517459, -0.60997585, -0.81280977, -0.94639576, -0.99935285,
#        -0.96716933, -0.8525871 , -0.66536808, -0.42146253, -0.14165016,
#         0.15023019,  0.42931158,  0.67181744,  0.85708732,  0.969337  ,
#         0.9990033 ,  0.94355877,  0.80772704,  0.60308041,  0.34705389,
#         0.06145986, -0.22937029, -0.50065906, -0.72929382, -0.89579585,
#        -0.98597988, -0.99216262, -0.91381733, -0.75761869, -0.53687416,
#        -0.27039024,  0.01912978,  0.30702002,  0.56875347,  0.78203154,
#         0.92868385,  0.99621624,  0.97887526,  0.87813826,  0.70258763,
#         0.46717951,  0.19196969, -0.09959513, -0.38267487, -0.63315233,
#        -0.82968792, -0.95553762, -0.99997959, -0.95922755, -0.8367534 ,
#        -0.64299143, -0.39444932, -0.11230181,  0.17941334,  0.45584324,
#         0.69343723,  0.87195332,  0.97618269,  0.99724546,  0.93334716,
#         0.78993165,  0.57921732,  0.31915615,  0.03190422, -0.2580658 ,
#        -0.52604972, -0.74921644, -0.90855311, -0.99048491, -0.98803162])

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.xlabel("This is my x data")
plt.ylabel("This is my y data")
plt.title("This is my Title")
plt.show()

# %%
x=np.random.rand(50)
y=np.random.rand(50)

# %%
x
# Out:
# array([0.46117933, 0.5208372 , 0.76187306, 0.11073163, 0.50994724,
#        0.98443412, 0.69820438, 0.33846237, 0.65375535, 0.1130427 ,
#        0.50092783, 0.88357174, 0.84988441, 0.26294801, 0.67654444,
#        0.34492372, 0.32858942, 0.76248214, 0.51625184, 0.16538558,
#        0.36028555, 0.61573045, 0.72816903, 0.5074323 , 0.88619971,
#        0.95032001, 0.38118307, 0.26835355, 0.78099266, 0.9935311 ,
#        0.19004823, 0.83364496, 0.41222987, 0.84857357, 0.89076636,
#        0.29711274, 0.60089175, 0.08450127, 0.30321405, 0.67050431,
#        0.38290788, 0.86901332, 0.14401832, 0.64262327, 0.80412035,
#        0.78285298, 0.50184381, 0.67048316, 0.48786983, 0.8407746 ])

# %%
y
# Out:
# array([0.6436953 , 0.93492831, 0.21006184, 0.76451524, 0.01205264,
#        0.77151555, 0.09255807, 0.70673931, 0.01354835, 0.14294879,
#        0.12778658, 0.26792537, 0.40626195, 0.78437136, 0.11535364,
#        0.37671073, 0.53922071, 0.40122973, 0.71519439, 0.65985231,
#        0.61938904, 0.52072059, 0.92777819, 0.65116632, 0.60252723,
#        0.65467167, 0.7721138 , 0.78336835, 0.05853224, 0.51612957,
#        0.73478555, 0.78300096, 0.70623002, 0.23085911, 0.45046893,
#        0.40820004, 0.23416222, 0.47008971, 0.08939547, 0.43876754,
#        0.15856098, 0.6299759 , 0.05460032, 0.03438854, 0.07707866,
#        0.69996016, 0.10202053, 0.65581262, 0.90072705, 0.77682163])

# %%
colors=np.random.rand(50)
sizes=500*np.random.rand(50)
plt.scatter(x,y, c=colors, s=sizes, alpha=0.5)
plt.xlabel("This is my x data")
plt.ylabel("This is my y data")
plt.title("This is my tittle of this graph")
# Out:
# Text(0.5, 1.0, 'This is my tittle of this graph')

# %%
x=['a','b','c','d','e']

# %%
y=np.random.rand(5)

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
y
# Out:
# array([0.8017568 , 0.28235493, 0.05093836, 0.22627244, 0.33954094])

# %%
plt.barh(x,y)
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
plt.figure(figsize=(8,4))
plt.plot(x,y,'--r')
plt.grid()

# %%
sizes=500*np.random.rand(50)
plt.scatter(x,y, c='#008000', alpha=1, marker='v')
plt.xlabel("This is my x data")
plt.ylabel("This is my y data")
plt.title("This is my tittle of this graph")
# Out:
# Text(0.5, 1.0, 'This is my tittle of this graph')

# %%
data=[1,2,3,1,2,4,2,4,5,5]

# %%
plt.hist(data)
plt.show()

# %%
a=[3,4,5,7,9]
b=[5,6,8,5,8]
color=['#00FF00','#008000', '#0000FF', '#FF00FF','#800080']
plt.scatter(a,b,c=color)
plt.show()

# %%
x=np.random.rand(50)
y=np.random.rand(50)
z=np.random.rand(50)
fig=plt.figure()
ax=fig.add_subplot(projection='3d')
ax.scatter(x,y,z)
plt.show()
