# %%
"""
Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
Matplotlib.

Ans: Matplotlib is a data visualization tool used for creating, animated, and interactive visualization.
     in python.
     
     Name of plots that can be ploted by using matplotlib: 
     1. Barchat.
     2. scatter.
     3. histogram.
     4. boxplot.
     5. piechat.
    """

# %%
"""
Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
plot a scatter plot.

Ans:

# %%
import numpy as np

# %%
num=np.random.seed((3,3))

# %%
x=3+np.random.normal(0,2,50)

# %%
x[0:4]
# Out:
# array([5.02636688, 4.70559568, 5.216375  , 5.23878131])

# %%
y=np.random.normal(0,2,len(x))

# %%
y[0:5]
# Out:
# array([ 2.46694209,  0.29797279, -1.06116429, -1.46105329,  1.29012397])

# %%
import matplotlib.pyplot as plt

# %%
color=500*np.random.rand(50)
size=200*np.random.rand(50)

# %%
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title('Normal_Gaussian_distriution')
plt.scatter(x,y, c=color, s=size)

# %%
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.

# %%
# For line 1:
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([0, 100, 200, 300, 400, 500])

# %%
x
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
y
# Out:
# array([  0, 100, 200, 300, 400, 500])

# %%
plt.subplot(2,1,2)
plt.plot(x,y)

# %%
# For line2:
plt.subplot(2,2,1)
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([50, 20, 40, 20, 60, 70])
plt.plot(x,y)

# %%
# For line3:
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([10, 20, 30, 40, 50, 60])

# %%
plt.subplot(2,2,2)
plt.plot(x,y)
plt.show()

# %%
# For line 4:
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([200, 350, 250, 550, 450, 150])
plt.subplot(2,2,1)
plt.plot(x,y)
plt.show()

# %%
"""
Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.

Ans: A bar plot or bar chart is a graph that represent the category of data with rectangular bar with length
     and height proportional to the values which is represent.
     
     A bar chart describes the comparisons between the discrete categories.
"""

# %%
import numpy as np

# %%
company= np.array(['apple', 'Miscrosoft', 'Google','AMD'])
profit=np.array([3000, 8000, 1000, 10000])

# %%
plt.bar(company, profit)
# Out:
# <BarContainer object of 4 artists>

# %%
"""
Q5: What is a box plot? Why is it used? Using the following data plot a box plot.

Ans:  box plot data visualization tool created to display the summary of the set of 
      data values having properties like minimum, first quartile, median third quartile and maximum.
      
"""

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)
data=[box1, box2]

# %%
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f70116d1e10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f70116d2350>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f70116d1b70>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7f70116d2890>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f70116d2b30>,
# ...
#  'means': []}
